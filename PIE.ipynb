# %%
#matplotlib inline
from matplotlib import pyplot as plt

plt.rc('axes', unicode_minus=False) 
plt.rc('font', family='Malgun Gothic')

import pandas as pd

# %%
# pie_df 정의 및 shape 출력
pie_df = pd.read_excel("C:/Users/theny/share/data/sample-pie.xlsx", index_col='가수')
print(pie_df.shape)
pie_df.head()
# Out:
# (48, 1)
#                  곡수
# 가수
# Wanna One (워너원)  15
# 방탄소년단            13
# EXO              12
# 비투비               5
# 폴킴                3

# %%
# pie_df 차트 그리기
pie_df.iloc[:10].plot(kind='pie', y='곡수', legend=False, figsize=(5,5))
# Out:
# <AxesSubplot:ylabel='곡수'>
