# %%
#matplotlib inline
from matplotlib import pyplot as plt

plt.rc('axes', unicode_minus=False) 
plt.rc('font', family='Malgun Gothic')

import pandas as pd

# %%
# scatter_df 정의 및 차트 그리기
scatter_df = pd.read_excel('D:/share/data/sample-scatter.xlsx')
scatter_df.plot(kind='scatter', x='S&P500 - Ratio', y='KOSPI200 - Ratio', figsize=(10,10))
# Out:
# <AxesSubplot:xlabel='S&P500 - Ratio', ylabel='KOSPI200 - Ratio'>

# %%
# 추세선과 함께 나타내기 (seaborn 활용)
import seaborn as sns
sns.regplot(data=scatter_df, x='S&P500 - Ratio', y='KOSPI200 - Ratio')
# Out:
# <AxesSubplot:xlabel='S&P500 - Ratio', ylabel='KOSPI200 - Ratio'>
